# %% [markdown]
# # Mengukur Performa Penjualan Ritel Online

# %% [markdown]
# ### Homework Rakamin Trial Class - Mini Case

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
pd.__version__
# Out:
# '1.4.4'

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.__version__
# Out:
# '3.5.2'

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.11.2'

# %%
import numpy as np
np.__version__
# Out:
# '1.21.5'

# %%
df = pd.read_csv('online_retail_II.csv')
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %% [markdown]
# ## Section 1

# %% [markdown]
# ### Create New Feature: Year

# %%
df['Year']= pd.DatetimeIndex(df['InvoiceDate']).year
df['Year']
# Out:
# 0          2009
# 1          2009
# 2          2009
# 3          2009
# 4          2009
#            ...
# 1067366    2011
# 1067367    2011
# 1067368    2011
# 1067369    2011
# 1067370    2011
# Name: Year, Length: 1067371, dtype: int64

# %%
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Year
# ...

# %% [markdown]
# ### convert obj type to date time

# %%
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'])

# %%
df.dtypes
# Out:
# Invoice                object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# Price                 float64
# Customer ID           float64
# Country                object
# Year                    int64
# dtype: object

# %% [markdown]
# ### Filtering Data

# %%
data_qyt = df['Quantity']>= 1
df[data_qyt]
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID         Country  Year
# ...

# %%
finished_inv = df['Invoice'] != 'C'
df[finished_inv]
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID         Country  Year
# ...

# %% [markdown]
# ### Filtering

# %%
df[(finished_inv) & (data_qyt)]
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID         Country  Year
# ...

# %% [markdown]
# ### Create New Feature: Revenue

# %%
df['Revenue'] = df['Quantity'] * df['Price']
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID         Country  Year  Revenue
# ...

# %% [markdown]
# ### Average of Revenue per Year

# %%
revenue_2009 = df['Year'] == 2009
df[revenue_2009]
# Out:
#       Invoice StockCode                          Description  Quantity  \
# 0      489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1      489434    79323P                   PINK CHERRY LIGHTS        12
# 2      489434    79323W                  WHITE CHERRY LIGHTS        12
# 3      489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4      489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...       ...       ...                                  ...       ...
# 45223  493408    90058B  CRYSTAL STUD EARRINGS ASSORTED COL          1
# 45224  493408     21933      PINK VINTAGE PAISLEY PICNIC BAG         1
# 45225  493408     21937              STRAWBERRY   PICNIC BAG         1
# 45226  493408     21936            RED/WHITE SPOT PICNIC BAG         1
# 45227  493409     20747                   PICCADILLY TEA SET        48
#
#               InvoiceDate  Price  Customer ID         Country  Year  Revenue
# ...

# %%
average_2009 = revenue_2009.sum() / len(revenue_2009)
average_2009
# Out:
# 0.04237327039988907

# %%
revenue_2010 = df['Year'] == 2010
df[revenue_2010]
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 45228    493410   TEST001          This is a test product.         5
# 45229   C493411     21539          RETRO SPOTS BUTTER DISH        -1
# 45230    493412   TEST001          This is a test product.         5
# 45231    493413     21724  PANDA AND BUNNIES STICKER SHEET         1
# 45232    493413     84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...       ...                              ...       ...
# 567937   539991     21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 567938   539991     72741            GRAND CHOCOLATECANDLE         4
# 567939   539992     21470    FLOWER VINE RAFFIA FOOD COVER         1
# 567940   539992     22258          FELT FARM ANIMAL RABBIT         1
# 567941   539992     21155            RED RETROSPOT PEG BAG         1
#
#                InvoiceDate  Price  Customer ID         Country  Year  Revenue
# ...

# %%
average_2010 = revenue_2010.sum() / len(revenue_2010)
average_2010
# Out:
# 0.4897210060981608

# %%
revenue_2011 = df['Year'] == 2011
df[revenue_2011]
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 567942   539993     22386          JUMBO BAG PINK POLKADOT        10
# 567943   539993     21499               BLUE POLKADOT WRAP        25
# 567944   539993     21498              RED RETROSPOT WRAP         25
# 567945   539993     22379         RECYCLING BAG RETROSPOT          5
# 567946   539993     20718        RED RETROSPOT SHOPPER BAG        10
# ...         ...       ...                              ...       ...
# 1067366  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                          POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID         Country  Year  Revenue
# ...

# %%
average_2011 = revenue_2011.sum() / len(revenue_2011)
average_2011
# Out:
# 0.46790572350195014

# %%
df.plot(x='Year',y='Revenue',kind='line')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df[['Revenue','Year']].plot(kind='line')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Interpretation

# %% [markdown]
# * Terdapat trend positif terhadap revenue dari tahun 2009 sampai dengan tahun 2011
# * Terdapat beberapa item yang memiliki reveneu sangat tinggi

# %% [markdown]
# ## Section 2

# %% [markdown]
# ### Filtering Data

# %% [markdown]
# #### Customers who finished their purchases

# %%
df.query('`Customer ID` != " "  ')
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
finished = df.query('`Customer ID` != " "  ')
finished
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %% [markdown]
# #### Customers who canceled their purchases

# %% [markdown]
# ### Di dalam tidak terdapat pelanggan dengan invoce yang mengandung huruf 'C'

# %%
df.Invoice.unique()
# Out:
# array(['489434', '489435', '489436', ..., '581585', '581586', '581587'],
#       dtype=object)

# %% [markdown]
# ### Number of Finished and Canceled Transactions Each Year

# %% [markdown]
# ### Cancellation Rate

# %% [markdown]
# ### Interpretation
